# %%
from statsbombpy import sb

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 0                9         27        Germany           1. Bundesliga
# 1             1267        107         Africa  African Cup of Nations
# 2               16          4         Europe        Champions League
# 3               16          1         Europe        Champions League
# 4               16          2         Europe        Champions League
# ..             ...        ...            ...                     ...
# 66              55         43         Europe               UEFA Euro
# 67              35         75         Europe      UEFA Europa League
# 68              53        106         Europe       UEFA Women's Euro
# 69              72        107  International       Women's World Cup
# 70              72         30  International       Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
sb.matche()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sb.matche()
#
# AttributeError: module 'statsbombpy.sb' has no attribute 'matche'

# %%
sb.lineups(match_id=303299)["Eintracht Frankfurt"]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sb.lineups(match_id=303299)["Eintracht Frankfurt"]
#
# File ~/Desktop/statsbomb_test/venvheatmap/lib/python3.10/site-packages/statsbombpy/sb.py:76, in lineups(match_id, fmt, creds)
#      74     lineups = api_client.lineups(match_id, creds=creds)
#      75 else:
# ---> 76     lineups = public.lineups(match_id)
#      77 if fmt == "dataframe":
#      78     lineups_ = {}
#
# File ~/Desktop/statsbomb_test/venvheatmap/lib/python3.10/site-packages/statsbombpy/public.py:31, in lineups(match_id)
#      29 def lineups(match_id: int):
#      30     path = OPEN_DATA_PATHS["lineups"].format(match_id=match_id)
# ---> 31     lineups = get_response(path)
#      32     lineups = ents.lineups(lineups)
#      33     return lineups
#
# ...
